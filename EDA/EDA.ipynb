# %% [markdown]
# ### Importing some packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv("C:\\Users\\Vahe\\PycharmProjects\\pythonProject\\Training_Batch_Files\\phishing_09032022_ 082200.csv")
df.head()
# Out:
#    qty_dot_url  qty_hyphen_url  qty_underline_url  qty_slash_url  \
# 0            3               0                  0              1
# 1            5               0                  1              3
# 2            2               0                  0              1
# 3            4               0                  2              5
# 4            2               0                  0              0
#
#    qty_questionmark_url  qty_equal_url  qty_at_url  qty_and_url  \
# 0                     0              0           0            0
# 1                     0              3           0            2
# 2                     0              0           0            0
# 3                     0              0           0            0
# 4                     0              0           0            0
#
#    qty_exclamation_url  qty_space_url  ...  qty_ip_resolved  qty_nameservers  \
# 0                    0              0  ...                1                2
# ...

# %% [markdown]
# ### EDA

# %% [markdown]
# Checking for general info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88647 entries, 0 to 88646
# Columns: 112 entries, qty_dot_url to phishing
# dtypes: float64(1), int64(111)
# memory usage: 75.7 MB

# %% [markdown]
# Checking missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Checking for zero variance features

# %%
zero_variance_features = []
for col in df.columns:
    if df[col].std() == 0:
        zero_variance_features.append(col)

print(zero_variance_features)
# Out:
# ['qty_slash_domain', 'qty_questionmark_domain', 'qty_equal_domain', 'qty_and_domain', 'qty_exclamation_domain', 'qty_space_domain', 'qty_tilde_domain', 'qty_comma_domain', 'qty_plus_domain', 'qty_asterisk_domain', 'qty_hashtag_domain', 'qty_dollar_domain', 'qty_percent_domain']

# %% [markdown]
# #### Univariate analysis

# %% [markdown]
# Creating some necessary lists

# %%
# Creating list of categorical variables including the target (phishing)
cat_list = ['email_in_url', 'domain_in_ip', 'server_client_domain', 
            'tld_present_params', 'domain_spf', 'tls_ssl_certificate',
            'url_google_index', 'domain_google_index', 'url_shortened',
            'phishing']

# Creating features' list excluding zero variance features
feat_list = [col for col in df.columns if col not in zero_variance_features]

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[:16]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[16:32]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[32:48]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[48:64]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[64:80]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[80:96]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[96:]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df)
    else:
        sns.kdeplot(x=col, data=df)
        
    i += 1
    
plt.tight_layout()

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
# Removing phishing column from feat_list and cat_list

# %%
cat_list.remove('phishing')
feat_list.remove('phishing')

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[:16]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()
# Out:
# C:\Users\Vahe\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Vahe\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Vahe\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Vahe\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[16:32]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()
# Out:
# C:\Users\Vahe\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[32:48]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[48:64]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[64:80]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[80:96]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()

# %%
fig = plt.figure(figsize=(12, 8))
i = 1
for col in feat_list[96:]:
    plt.subplot(4, 4, i)
    if col in cat_list:
        sns.countplot(x=col, data=df, hue='phishing')
    else:
        sns.kdeplot(x=col, data=df, hue='phishing')
        
    i += 1
    
plt.tight_layout()
